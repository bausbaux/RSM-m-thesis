# %% [markdown]
# ## Exploration and analysis

# %%
import pandas as pd
df = pd.read_csv("df_cleaned.csv")

df.sample(20)
# Out:
# C:\Users\Ethan D\AppData\Local\Temp\ipykernel_10472\807631756.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("df_cleaned.csv")
#          rating                                              title  \
# 5184798     2.0                         Low prices that’s about it
# 7679022     1.0  Inexperienced intern level executives managing...
# 2836561     2.0  Trainers say one thing the job is actually ano...
# 5423206     4.0                                Lots of opportunity
# 6801209     4.0                            Great work life balance
# 6223899     3.0                                             Review
# 3638953     4.0                                        interesting
# 3897229     5.0                                  My Express Review
# 51230       5.0                                 Top notch insights
# 6718575     3.0                                    Leadership Woes
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7857331 entries, 0 to 7857330
# Data columns (total 16 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   rating                      float64
#  1   title                       object
#  2   status                      object
#  3   pros                        object
#  4   cons                        object
#  5   date                        object
#  6   job                         object
#  7   company_name                object
#  8   CEO_Approval_Sentiment      float64
#  9   Business_Outlook_Sentiment  float64
#  10  Recommmend_sentiment        float64
#  11  company_size                object
#  12  industry                    object
#  13  eu_status                   object
#  14  founded_year                object
#  15  under_gdpr                  object
# dtypes: float64(4), object(12)
# memory usage: 959.1+ MB
# rating                          124
# ...

# %%
df = df.dropna(subset=[
    'rating',
    'status',
    'pros',
    'cons',
    'date',
    'job',
    'CEO_Approval_Sentiment',
    'Business_Outlook_Sentiment',
    'Recommmend_sentiment'
])

# %%
df.sample(10)
# Out:
#          rating                                              title  \
# 946155      4.0       Good benefits and raises for good performers
# 7620575     4.0                                          Just okay
# 4022331     4.0                                                 Ok
# 6402888     2.0                                    Don't recomment
# 3848032     5.0                                       Good Company
# 5464395     4.0  JHU APL is a great place to work if you value ...
# 7557208     5.0                       Changing the way of wireless
# 1401848     4.0                                      Great company
# 5426119     4.0                                               Good
# 2533983     3.0                                              Sales
#
#                                       status  \
# 946155    Former Employee, more than 3 years
# 7620575                     Current Employee
# 4022331                      Former Employee
# ...

# %%
unique_companies = df['company_name'].dropna().unique()

# Optional: turn it into a DataFrame and save to CSV
#pd.DataFrame(unique_companies, columns=['company_name']).to_csv('unique_company_names_current.csv', index=False)

# Count how many unique companies
#print(f"Number of unique companies: {len(unique_companies)}")

# %%
# Total number of non-missing ratings
rating_count = df['rating'].notnull().sum()
print(f"Total number of ratings: {rating_count}")

# %%
# Group by company and calculate average rating + count
rating_summary = df.groupby('company_name').agg(
    avg_rating=('rating', 'mean'),
    rating_count=('rating', 'count')
).reset_index()

# Optional: Filter to only include companies with at least N ratings (e.g., 30)
rating_summary = rating_summary[rating_summary['rating_count'] >= 30]

# Sort by average rating descending
rating_summary = rating_summary.sort_values(by='avg_rating', ascending=False)

# Show top 10
print(rating_summary.head(10))
# Out:
#                         company_name  avg_rating  rating_count
# 1546         Universitas Gadjah Mada    4.589792          4232
# 166                 Bain and Company    4.533631          5382
# 386   Continental Software Solutions    4.499505         24264
# 696                          HubSpot    4.488390          2670
# 231     Brigham Young University BYU    4.485022          4006
# 230   Brigham Young University (BYU)    4.483530         19854
# 303       Carnegie Mellon University    4.439096          2036
# 1702                            Zoho    4.416430          3165
# 611                           Google    4.416172         27270
# 13                            AIESEC    4.400536          1493

# %%
# Count number of ratings per company
top20_by_count = df.groupby('company_name')['rating'].count().reset_index()

# Rename column for clarity
top20_by_count.columns = ['company_name', 'rating_count']

# Sort by rating count descending
top20_by_count = top20_by_count.sort_values(by='rating_count', ascending=False)

# Keep only top 20
top20_by_count = top20_by_count.head(50)

# Display result
print(top20_by_count)
# Out:
#                                company_name  rating_count
# 77                                   Amazon        163393
# 1399              Tata Consultancy Services        107215
# 1636                                Walmart        102151
# 356          Cognizant Technology Solutions         84166
# 926                              McDonald s         76776
# 35                                Accenture         69023
# 1396                                 Target         67884
# 642                                  HP Inc         63787
# 1342                              Starbucks         55325
# 741                                 Infosys         53187
# 707                                     IBM         52072
# 1150                                    PwC         51184
# 1515                                US Navy         49151
# 636                                 HCLTech         48419
# 1673                                  Wipro         47071
# ...

# %%
print(df['under_gdpr'].value_counts())
# Out:
# under_gdpr
# Yes                                              3177198
# No                                               1804715
# Yes"                                             1448891
# No"                                              1047452
# Unknown                                           200284
# "Yes"                                              77790
# "No"                                               59227
#  Yes"                                              25219
#  the requested information is not applicable.       8841
#  No"                                                3483
#  Yes                                                2853
# Information not available"                          1192
# Name: count, dtype: int64

# %%
# Standardize and clean the 'under_gdpr' column
df['under_gdpr'] = (
    df['under_gdpr']
    .astype(str)  # Ensure all entries are strings
    .str.strip()  # Remove leading/trailing whitespace
    .str.strip('"')  # Remove quotation marks
    .str.lower()  # Convert to lowercase
    .map({
        'yes': 'Yes',
        'no': 'No',
        'unknown': 'Unknown',
        'information not available': 'Unknown',
        'the requested information is not applicable.': 'Unknown'
    })  # Map known cases
    .fillna('Unknown')  # Default unknown for unmapped values
)

# Check the cleaned distribution
print(df['under_gdpr'].value_counts())
# Out:
# under_gdpr
# Yes        4731951
# No         2914877
# Unknown     210317
# Name: count, dtype: int64

# %%
# Remove rows where the GDPR status is 'Unknown'
df = df[df['under_gdpr'] != 'Unknown']

# Check shape to confirm how many remain
print(df.shape)
# Out:
# (7646828, 16)

# %%
print(df['under_gdpr'].value_counts())
# Out:
# under_gdpr
# Yes    4731951
# No     2914877
# Name: count, dtype: int64

# %%
print(top20_by_count)
# Out:
#                                company_name  rating_count
# 77                                   Amazon        163393
# 1399              Tata Consultancy Services        107215
# 1636                                Walmart        102151
# 356          Cognizant Technology Solutions         84166
# 926                              McDonald s         76776
# 35                                Accenture         69023
# 1396                                 Target         67884
# 642                                  HP Inc         63787
# 1342                              Starbucks         55325
# 741                                 Infosys         53187
# 707                                     IBM         52072
# 1150                                    PwC         51184
# 1515                                US Navy         49151
# 636                                 HCLTech         48419
# 1673                                  Wipro         47071
# ...

# %%
df.sample(10)
# Out:
#          rating                                title  \
# 1019730     1.0          Worst Place to work ever!!!
# 928208      2.0                    Internal Medicine
# 5314082     4.0                             Good job
# 6125265     2.0    LOTS of tasks, no time to do then
# 3672871     1.0                             Disaster
# 6800146     4.0  Great co workers, great pay but....
# 7396288     5.0              Best company to work-in
# 1888476     4.0                             was fine
# 6568798     3.0                     Systems Engineer
# 3680447     4.0                     Good Experiences
#
#                                      status  \
# 1019730                     Former Employee
# 928208                     Current Employee
# 5314082   Former Employee, more than 1 year
# 6125265  Former Employee, more than 3 years
# 3672871  Former Employee, more than 3 years
# 6800146  Current Employee, less than 1 year
# 7396288                    Current Employee
# ...

# %%
print(df['company_size'].value_counts())
# Out:
# company_size
# Large        4984766
# "Large       2490221
# "Large"       133913
# "Mid-size      34824
# "Small"         3104
# Name: count, dtype: int64

# %%
# Clean and standardize the company_size column
df['company_size'] = (
    df['company_size']
    .astype(str)                  # Ensure values are strings
    .str.strip()                  # Remove leading/trailing whitespace
    .str.strip('"')               # Remove quotes
    .str.title()                  # Capitalize each word (e.g., large → Large, mid-size → Mid-Size)
)

# Check the cleaned distribution
print(df['company_size'].value_counts())
# Out:
# company_size
# Large       7608900
# Mid-Size      34824
# Small          3104
# Name: count, dtype: int64

# %%
print(df['industry'].value_counts())
# Out:
# industry
# Retail                                 934423
# Information Technology and Services    645867
# Banking                                320096
# Healthcare                             309044
# Telecommunications                     263427
#                                         ...
# Furniture Retail                         1027
# Maritime and Renewable Energy            1023
# Furniture retail                         1019
# "Telecommunications"                     1012
# EdTech                                   1010
# Name: count, Length: 435, dtype: int64

# %%
# Clean and standardize the 'industry' column
df['industry'] = (
    df['industry']
    .astype(str)                 # Convert to string
    .str.strip()                 # Remove leading/trailing whitespace
    .str.strip('"')              # Remove surrounding quotes
    .str.lower()                 # Convert to lowercase for consistency
    .str.title()                 # Capitalize each word (e.g., 'telecommunications' → 'Telecommunications')
)

# Check the cleaned result
print(df['industry'].value_counts().head(20))  # Top 20 industries
# Out:
# industry
# Retail                                 935680
# Information Technology And Services    649190
# Education                              323648
# Banking                                321562
# Healthcare                             309044
# Financial Services                     269108
# Telecommunications                     264439
# Professional Services                  255636
# Food Service                           203452
# E-Commerce                             191317
# Insurance                              187853
# Automotive                             143896
# Information Technology                 114968
# Software                               114919
# Defense & Space                         98991
# Restaurant                              93261
# Pharmaceuticals                         85839
# Food And Beverage                       85800
# Home Improvement Retail                 85234
# Aerospace And Defense                   80808
# Name: count, dtype: int64

# %%
industry_df = pd.DataFrame(df['industry'].dropna().unique(), columns=['industry'])
industry_df = industry_df.sort_values(by='industry').reset_index(drop=True)

# Step 3: Export to CSV
#industry_df.to_csv('unique_industries.csv', index=False)

# %%
# Step 1: Define your extended mapping dictionary
industry_mapping = {
    # Retail group
    "Retail": "Retail",
    "Furniture Retail": "Retail",
    "Apparel Retail": "Retail",
    "Home Improvement Retail": "Retail",
    "Used Car Retail": "Retail",
    "Retail (Hardware)": "Retail",
    "Retail (Sporting Goods)": "Retail",
    "Retail (Eyewear)": "Retail",
    "Retail - Jewelry": "Retail",
    "Apparel": "Retail",
    "Apparel & Footwear": "Retail",
    "Book Retail": "Retail",
    "Fashion": "Retail",
    "Fashion & Apparel": "Retail",
    "Fashion Accessories": "Retail",
    "Footwear Manufacturing": "Retail",
    "Grocery Retail": "Retail",
    "Hardware Retail": "Retail",
    "Furniture": "Retail",
    "Jewelry": "Retail",
    "Jewelry And Accessories": "Retail",
    "Optical Retail": "Retail",
    "Outdoor Apparel And Equipment": "Retail",
    "Office Supplies": "Retail",
    "Pharmacy Retail": "Retail",
    
    # IT and Software
    "Information Technology And Services": "IT & Software",
    "Information Services": "IT & Software",
    "Computer Software": "IT & Software",
    "Software": "IT & Software",
    "Software Development": "IT & Software",
    "It Services": "IT & Software",
    "Computer Hardware": "IT & Software",
    "Computer Networking": "IT & Software",
    "Cybersecurity": "IT & Software",
    "Data Analytics & Risk Assessment": "IT & Software",
    "Data Center & Internet Exchange Services": "IT & Software",
    "Data Management And Storage": "IT & Software",
    "Digital Consultancy": "IT & Software",
    "Digital Product Engineering Services": "IT & Software",
    "Digital Transformation Services": "IT & Software",
    "Analytics Software": "IT & Software",
    "E-Commerce": "IT & Software",
    "Electronics/Information Technology": "IT & Software",
    "Information Management And Storage": "IT & Software",
    "Information Technology": "IT & Software",
    "Information Technology & Services": "IT & Software",
    "Information Technology Services": "IT & Software",
    "Internet Services": "IT & Software",
    "Internet Services And Products": "IT & Software",
    "Internet Technology": "IT & Software",
    "Job Search Engine": "IT & Software",
    "Local Search Engine": "IT & Software",
    "Online Employment": "IT & Software",
    "Online Marketplace": "IT & Software",
    "Localization And Ai Training Data": "IT & Software",


    # Healthcare
    "Healthcare": "Healthcare",
    "Healthcare Services": "Healthcare",
    "Medical Devices": "Healthcare",
    "Medical Technology": "Healthcare",
    "Pharmaceuticals": "Healthcare",
    "Pharmacy": "Healthcare",
    "Biopharmaceutical": "Healthcare",
    "Biotechnology": "Healthcare",
    "Dental Care": "Healthcare",
    "Dental Care Services": "Healthcare",
    "Dental Insurance": "Healthcare",
    "Fitness": "Healthcare",
    "Fitness And Health": "Healthcare",
    "Health And Fitness": "Healthcare",
    "Health And Wellness": "Healthcare",
    "Health Insurance": "Healthcare",
    "Healthcare & Diagnostics": "Healthcare",
    "Healthcare And Human Services": "Healthcare",
    "Healthcare Technology": "Healthcare",
    "Life Science": "Healthcare",
    "Life Sciences": "Healthcare",
    "Life Sciences & Diagnostics": "Healthcare",
    "Medical Devices And Health Care": "Healthcare",
    "Medical Equipment": "Healthcare",
    "Medical Supplies": "Healthcare",
    "Medical Waste Management": "Healthcare",
    "Pharmaceutical": "Healthcare",
    "Pharmacy And Health & Wellness": "Healthcare",
    "Pharmacy Benefit Management": "Healthcare",

    # Education
    "Education": "Education",
    "Education Services": "Education",
    "Edtech": "Education",
    "Childcare And Early Education": "Education",
    "Education & Health Services": "Education",
    "Education & Healthcare": "Education",
    "Education & Training Services": "Education",
    "Education And Training Services": "Education",
    "Education Technology": "Education",
    "Higher Education": "Education",
    "Online Education": "Education",


    # Financial Services
    "Banking": "Financial Services",
    "Financial Services": "Financial Services",
    "Insurance": "Financial Services",
    "Investment Management": "Financial Services",
    "Accounting": "Financial Services",
    "Accounting And Consulting": "Financial Services",
    "Credit Reporting": "Financial Services",
    "Finance": "Financial Services",
    "Financial Software & Media": "Financial Services",
    "Financial Technology": "Financial Services",

    # Logistics
    "Logistics": "Logistics & Transport",
    "Shipping And Logistics": "Logistics & Transport",
    "Transportation": "Logistics & Transport",
    "Truck Rental": "Logistics & Transport",
    "Truck Leasing": "Logistics & Transport",
    "Courier And Delivery Services": "Logistics & Transport",
    "Airline": "Logistics & Transport",
    "Airlines": "Logistics & Transport",
    "Car Rental": "Logistics & Transport",
    "Logistics And Supply Chain": "Logistics & Transport",
    "Mail And Shipping Services": "Logistics & Transport",
    "Package Delivery And Supply Chain Management": "Logistics & Transport",
    "Postal Services": "Logistics & Transport",




    # Advertising & Marketing
    "Advertising": "Advertising & Marketing",
    "Advertising & Marketing": "Advertising & Marketing",
    "Advertising And Marketing": "Advertising & Marketing",
    "Advertising And Public Relations": "Advertising & Marketing",
    "Digital Marketing": "Advertising & Marketing",
    "Digital Marketing Services": "Advertising & Marketing",
    "Market Research": "Advertising & Marketing",
    "Marketing": "Advertising & Marketing",

    # Beauty & Cosmetics
    "Beauty & Cosmetics": "Beauty & Cosmetics",
    "Beauty And Cosmetics": "Beauty & Cosmetics",
    "Beauty Products": "Beauty & Cosmetics",
    "Beauty Supplies": "Beauty & Cosmetics",
    "Cosmetics": "Beauty & Cosmetics",

    # Food & Beverage
    "Alcohol Wholesale": "Food & Beverage",
    "Alcoholic Beverages": "Food & Beverage",
    "Beverage": "Food & Beverage",
    "Beverage (Beer)": "Food & Beverage",
    "Beverage And Brewing": "Food & Beverage",
    "Beverage Manufacturing": "Food & Beverage",
    "Beverages": "Food & Beverage",
    "Brewing And Pub Retailing": "Food & Beverage",
    "Food & Beverage Services": "Food & Beverage",
    "Food & Beverages": "Food & Beverage",
    "Food And Beverage": "Food & Beverage",
    "Food Delivery": "Food & Beverage",
    "Food Distribution": "Food & Beverage",
    "Food Processing": "Food & Beverage",
    "Food Retail & Service": "Food & Beverage",
    "Food Service": "Food & Beverage",
    "Food Services": "Food & Beverage",
    "Food Services And Facilities Management": "Food & Beverage",
    "Foodservice": "Food & Beverage",
    "Foodservice Distribution": "Food & Beverage",
    "Online Food Ordering": "Food & Beverage",

    # Entertainment
    "Amusement Park And Entertainment": "Entertainment",
    "Amusement Park And Resort": "Entertainment",
    "Amusement Parks And Attractions": "Entertainment",
    "Animation And Film Production": "Entertainment",
    "Bookmaking And Gaming": "Entertainment",
    "Entertainment": "Entertainment",
    "Entertainment And Hospitality": "Entertainment",
    "Film And Entertainment": "Entertainment",
    "Film And Television": "Entertainment",
    "Film And Television Production": "Entertainment",
    "Film And Tv Production": "Entertainment",
    "Film Exhibition": "Entertainment",
    "Mass Media": "Entertainment",
    "Media": "Entertainment",
    "Media And Entertainment": "Entertainmemt",
    "News & Media": "Entertainment",
    "Movie Theaters": "Entertainment",
    "Music Retail": "Entertainment",

    # Aerospace & Defense
    "Aerospace": "Aerospace & Defense",
    "Aerospace And Defense": "Aerospace & Defense",
    "Aerospace And Transportation": "Aerospace & Defense",
    "Aviation": "Aerospace & Defense",
    "Aviation Services": "Aerospace & Defense",
    "Defense & Aerospace": "Aerospace & Defense",
    "Defense & Security": "Aerospace & Defense",
    "Defense & Space": "Aerospace & Defense",
    "Defense And Law Enforcement": "Aerospace & Defense",

    # --- Non-Profit ---
    "Non-Profit Organization": "Non-Profit",
    "Non-Profit/Education": "Non-Profit",
    "Non-Profit/Thrift Stores": "Non-Profit",
    "Nonprofit Organization": "Non-Profit",

    # Automotive
    "Automobile Manufacturing": "Automotive",
    "Automotive": "Automotive",
    "Automotive Parts": "Automotive",
    "Auto Parts Retail": "Automotive",
    "Auto Service & Repair": "Automotive",
    "Automotive Software": "Automotive",

    # Construction
    "Construction": "Construction & Engineering",
    "Construction & Real Estate": "Construction & Engineering",
    "Construction And Building Materials": "Construction & Engineering",
    "Construction And Engineering": "Construction & Engineering",
    "Construction And Mining Equipment": "Construction & Engineering",
    "Construction Materials": "Construction & Engineering",
    "Architecture & Engineering": "Construction & Engineering",
    "Engineering & Consulting": "Construction & Engineering",
    "Engineering And Design": "Construction & Engineering",
    "Engineering And Design Consultancy": "Construction & Engineering",
    "Engineering And Technology": "Construction & Engineering",
    "Engineering And Technology Services": "Construction & Engineering",
    "Engineering Services": "Construction & Engineering",
    "Hvac": "Construction & Engineering",
    "Hvac And Climate Control": "Construction & Engineering",

    # Consulting & Business Services
    "Consulting": "Consulting & Business Services",
    "Consulting And Engineering": "Consulting & Business Services",
    "Consulting Services": "Consulting & Business Services",
    "Business Process Management": "Consulting & Business Services",
    "Business Process Outsourcing": "Consulting & Business Services",
    "Business Process Outsourcing (Bpo)": "Consulting & Business Services",
    "Business Process Services": "Consulting & Business Services",
    "Business Services": "Consulting & Business Services",
    "Bpo And Customer Experience Management": "Consulting & Business Services",
    "Bpo And It Services": "Consulting & Business Services",
    "Management Consulting": "Consulting & Business Services",
    "Professional Services": "Consulting & Business Services",
    "Outsourcing And Energy Services": "Consulting & Business Services",
    "Outsourcing And Technology Services": "Consulting & Business Services",
    "Outsourcing Services": "Consulting & Business Services",

     # Electronics & Manufacturing
    "Electrical Equipment Manufacturing": "Electronics & Manufacturing",
    "Electrical/Electronic Manufacturing": "Electronics & Manufacturing",
    "Electronics": "Electronics & Manufacturing",
    "Electronics Distribution": "Electronics & Manufacturing",
    "Electronics Manufacturing": "Electronics & Manufacturing",
    "Electronics Manufacturing Services": "Electronics & Manufacturing",
    "Elevator And Escalator Manufacturing": "Electronics & Manufacturing",
    "Industrial Automation": "Electronics & Manufacturing",
    "Industrial Gas Manufacturing": "Electronics & Manufacturing",
    "Industrial Gases": "Electronics & Manufacturing",
    "Industrial Machinery & Equipment": "Electronics & Manufacturing",
    "Industrial Machinery And Equipment Manufacturing": "Electronics & Manufacturing",
    "Industrial Manufacturing": "Electronics & Manufacturing",
    "Industrial Services": "Electronics & Manufacturing",
    "Industrial Supply": "Electronics & Manufacturing",
    "Machinery Manufacturing": "Electronics & Manufacturing",
    "Manufacturing": "Electronics & Manufacturing",
    "Materials": "Electronics & Manufacturing",
    "Paint Manufacturing": "Electronics & Manufacturing",
    "Paints And Coatings": "Electronics & Manufacturing",
    "Paper & Forest Products": "Electronics & Manufacturing",
    "Oilfield Services": "Electronics & Manufacturing",

    # Government & Legal
    "Government": "Government & Legal",
    "Government Administration": "Government & Legal",
    "Government Agency": "Government & Legal",
    "Government Services": "Government & Legal",
    "Legal And Business Services": "Government & Legal",
    "Legal Services": "Government & Legal",
    "Public Administration": "Government & Legal",
    "Public Health And Safety": "Government & Legal",


    # Human Resources
    "Employment Services": "Human Resources",
    "Human Resource And Business Solutions": "Human Resources",
    "Human Resource Consulting": "Human Resources",
    "Human Resource Management": "Human Resources",
    "Human Resource Services": "Human Resources",
    "Human Resources": "Human Resources",
    
    # Environmental Services
    "Environmental & Facilities Services": "Environmental Services",
    "Environmental Services": "Environmental Services",

  # --- Consumer Services ---
    "Personal Care Products": "Consumer Goods and Servies",
    "Personal Care Services": "Consumer Goods and Services",
    "Lawn Care Services": "Consumer Goods and Services",
    "Pest Control": "Consumer Goods and Services",
    "Petcare": "Consumer Goods and Services",
    
    # Chemicals
    "Chemical Industry": "Chemicals",
    "Chemicals": "Chemicals",

    # Other / Uncategorized
    "Air Conditioning And Refrigeration": "Other",
    "Air Transport Communications And It Solutions": "Other",
    "Deathcare": "Other",
    "Direct Sales": "Other", 
    "Arts And Crafts": "Other",
    "Online Travel Agency": "Other",
    "Photography": "Other",
    "Power Management": "Energy",
    "Printing": "Other",
    "Printing And Communications": "Other"

}

#  (additions from 301 to 389)
industry_mapping.update({
    # Real Estate
    "Real Estate": "Real Estate",
    "Real Estate And Mortgage": "Real Estate",
    "Real Estate Information And Analytics": "Real Estate",

    # Recruitment & Staffing
    "Recruitment": "Human Resources",
    "Recruitment/Staffing": "Human Resources",
    "Staffing And Outsourcing": "Human Resources",
    "Staffing And Recruiting": "Human Resources",

    # Restaurant & Food Service
    "Restaurant": "Food & Beverage",
    "Restaurant And Entertainment": "Food & Beverage",
    "Restaurant And Retail": "Food & Beverage",
    "Restaurant Industry": "Food & Beverage",
    "Supermarket": "Food & Beverage",

    # Ride-Hailing & Mobility
    "Ride-Hailing": "Logistics & Transport",
    "Ride-Sharing": "Logistics & Transport",

    # Science & Research
    "Research And Development": "Research & Science",
    "Scientific Research & Development": "Research & Science",
    "Testing And Certification Services": "Research & Science",

    # Public & Transport
    "Public Relations": "Government & Legal",
    "Public Transportation": "Logistics & Transport",
    "Rail Transport": "Logistics & Transport",
    "Rail Transportation": "Logistics & Transport",

    # Semiconductor & Manufacturing
    "Semiconductor": "Electronics & Manufacturing",
    "Semiconductor Industry": "Electronics & Manufacturing",
    "Semiconductors": "Electronics & Manufacturing",
    "Steel And Metal Manufacturing": "Electronics & Manufacturing",
    "Steel And Mining": "Electronics & Manufacturing",
    "Steel Production": "Electronics & Manufacturing",
    "Textiles": "Electronics & Manufacturing",
    "Tire Manufacturing": "Electronics & Manufacturing",
    "Toy Manufacturing": "Electronics & Manufacturing",
    "Truck And Diesel Engine Manufacturing": "Electronics & Manufacturing",
    "Uniform Rental And Facility Services": "Electronics & Manufacturing",
    "Specialty Glass And Ceramics": "Electronics & Manufacturing",

    # Telecommunications
    "Telecommunications": "Telecommunications",
    "Telemarketing": "Telecommunications",
    "Television Broadcasting": "Telecommunications",

    # Travel
    "Travel & Hospitality": "Travel",
    "Travel & Tourism": "Travel",
    "Travel And Tourism": "Travel",
    "Travel Centers": "Travel",
    "Travel Management": "Travel",
    "Travel Services": "Travel",
    "Travel Technology": "Travel",

    # Software / IT (continued)
    "Software": "IT & Software",
    "Software & It Services": "IT & Software",
    "Software & Programming": "IT & Software",

    # Entertainment & Games
    "Video Game Industry": "Entertainment",
    "Sports": "Entertainment",
    "Sportswear": "Entertainment",
    "Sportswear Manufacturing": "Entertainment",

    # Media / Publishing
    "Publishing": "Entertainment",
    "Social Expression": "Entertainment",

    # Other / Misc
    "Self Storage": "Other",
    "Security And Investigations": "Other",
    "Security Services": "Other",
    "Veterinary Services": "Other",
    "Weight Loss Services": "Healthcare",
    "Rent-To-Own": "Consumer Goods and Services",
    "Utilities": "Energy",
    "Wholesale Distribution": "Wholesale & Distribution",
    "Wholesale Trade": "Wholesale & Distribution",
    "Religion": "Non-Profit",
    "Residential Cleaning": "Consumer Goods and Services"
})

# STEP 2: Apply mapping to DataFrame column (assumes your column is named 'industry')
df['industry_grouped'] = df['industry'].map(industry_mapping).fillna('Other')

# %%
df['industry_grouped'].value_counts()
# Out:
# industry_grouped
# IT & Software                     1423171
# Retail                            1166822
# Financial Services                 890023
# Food & Beverage                    643721
# Healthcare                         542479
# Consulting & Business Services     442812
# Other                              367219
# Education                          360661
# Aerospace & Defense                290399
# Electronics & Manufacturing        279423
# Telecommunications                 267317
# Logistics & Transport              171878
# Automotive                         166391
# Human Resources                    125101
# Entertainment                      116030
# Construction & Engineering          78966
# Non-Profit                          50500
# Real Estate                         45061
# Government & Legal                  43666
# Advertising & Marketing             31631
# Beauty & Cosmetics                  31250
# Travel                              26651
# ...

# %%
# Drop the original 'industry' column
df.drop(columns=['industry'], inplace=True)

# Rename 'industry_grouped' to 'industry'
df.rename(columns={'industry_grouped': 'industry'}, inplace=True)

# %%
df.sample(20)
# Out:
#          rating                                              title  \
# 2321998     1.0                                           Horrible
# 1783460     3.0                                              Buyer
# 2338227     3.0                                Good place to start
# 6573741     4.0            One of the best companies to work with.
# 7094396     4.0                  Good enough but kind of isolating
# 2284985     5.0                                    overall working
# 4749510     3.0                                          Dillard's
# 1464374     5.0                     Focused on Action and Movement
# 1973938     1.0                                      Style Advisor
# 3132681     4.0                       Security Delivery Specialist
# 7856811     2.0  "Good place to Earn only, no future and no per...
# 1246877     5.0  Great company to work for - however not many p...
# 7123195     4.0                                               Cars
# ...

# %%
print(df['status'].unique())       # Unique values
print(df['status'].value_counts()) # Value counts (frequency)
# Out:
# ['Current Employee, more than 8 years'
#  'Current Employee, more than 5 years' 'Former Employee'
#  'Former Employee, less than 1 year' 'Former Employee, more than 8 years'
#  'Current Employee' 'Former Employee, more than 1 year'
#  'Current Employee, more than 1 year'
#  'Current Employee, more than 3 years'
#  'Former Employee, more than 3 years'
#  'Current Employee, more than 10 years'
#  'Former Employee, more than 5 years' 'Current Employee, less than 1 year'
#  'Former Employee, more than 10 years']
# status
# Current Employee                        1829190
# Former Employee                         1228667
# Current Employee, more than 1 year       760116
# Former Employee, more than 1 year        627092
# Current Employee, more than 3 years      571403
# Current Employee, less than 1 year       549271
# Former Employee, less than 1 year        451495
# Former Employee, more than 3 years       396731
# Current Employee, more than 5 years      362050
# ...

# %%
print(df.describe())
# Out:
#              rating  CEO_Approval_Sentiment  Business_Outlook_Sentiment  \
# count  7.646828e+06            7.646828e+06                7.646828e+06
# mean   3.584487e+00            3.308063e-01                3.044068e-01
# std    1.220072e+00            6.055472e-01                6.465275e-01
# min    1.000000e+00           -1.000000e+00               -1.000000e+00
# 25%    3.000000e+00            0.000000e+00                0.000000e+00
# 50%    4.000000e+00            5.000000e-01                5.000000e-01
# 75%    5.000000e+00            1.000000e+00                1.000000e+00
# max    5.000000e+00            1.000000e+00                1.000000e+00
#
#        Recommmend_sentiment
# count          7.646828e+06
# mean           2.351499e-01
# std            8.044136e-01
# min           -1.000000e+00
# 25%            0.000000e+00
# 50%            0.000000e+00
# 75%            1.000000e+00
# max            1.000000e+00

# %%
print("Min date:", df['date'].min())
print("Max date:", df['date'].max())
# Out:
# Min date: 2008-01-25
# Max date: 2023-07-10

# %%
## function to map seniorty levels to use as a control variable
def map_seniority(status):
    if isinstance(status, str):
        # Handle 'Intern' as entry level
        if 'Intern' in status:
            return 'Entry-Level'
        
        # Handle employees with less than 1 year or around 1 year experience
        elif 'less than 1 year' in status:
            return 'Junior'
        
        # Handle employees with experience from 1 to 3 years (Junior)
        elif 'more than 1 year' in status and 'more than 3 years' not in status:
            return 'Junior'
        
        # Handle employees with 3 to 5 years of experience (Mid-Level)
        elif 'more than 3 years' in status and 'more than 5 years' not in status:
            return 'Mid-Level'
        
        # Handle employees with 5 to 10 years of experience (Senior)
        elif 'more than 5 years' or 'more than 8 years' in status and 'more than 10 years' not in status:
            return 'Senior'
        
        # Handle employees with more than 10 years of experience (Very Senior)
        elif 'more than 10 years' in status:
            return 'Very Senior'
        
        # Handle 'Former Employee' status
        elif 'Former' in status:
            return 'Former Employee'
        
    return 'Unknown'  # Default if no match is found

# Apply the updated mapping logic
df['seniority_level'] = df['status'].apply(map_seniority)

# Check the results
df.sample(20)
# Out:
#          rating                                      title  \
# 7828531     4.0                                    Cashier
# 3965908     2.0                            Good not great.
# 7818768     2.0                                 Scheduling
# 5073186     5.0                      good starting company
# 2900676     3.0                            Could be better
# 3335736     4.0               Good place to work part time
# 1013997     4.0        Good Solid Company w/ Many Benefits
# 643218      3.0                              Great company
# 4603013     4.0                                Linux admin
# 35603       5.0                         Research Assistant
# 4422407     4.0                   Good people not good pay
# 4708277     4.0                           Militant culture
# 777640      5.0                              Specialist II
# 4709961     2.0                             tsa just a job
# 7359785     4.0                  Solid company to work for
# ...

# %%
# Ensure 'date' column is in datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Define GDPR implementation date and range
gdpr_date = pd.to_datetime('2018-05-25')
start_date = gdpr_date - pd.DateOffset(years=2)
end_date = gdpr_date + pd.DateOffset(years=2)

# Filter the DataFrame
df_gdpr_window = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

# Display sample to confirm
print(df_gdpr_window.sample(5))
# Out:
#          rating                  title                              status  \
# 6451311     3.0  Post Office Assistant   Former Employee, more than 1 year
# 2555713     3.0          Large Company  Former Employee, more than 8 years
# 5704440     3.0           Decent Place  Current Employee, more than 1 year
# 7500658     2.0                Manager                    Current Employee
# 2383679     5.0        Sales associate  Current Employee, more than 1 year
#
#                                                       pros  \
# 6451311               Great work environment and benefits.
# 2555713  large company with many positions around the w...
# 5704440                            The Co Workers are fun.
# 7500658  Learning opportunities for all employees who s...
# 2383679  I love working at the store. The people are gr...
#
#                                                       cons       date  \
# 6451311  Not enough hours.  Had to work 3 jobs to make ... 2018-04-06
# ...

# %%
 len(df_gdpr_window)
# Out:
# 2151491

# %%
 df_gdpr_window['company_name'].nunique()
# Out:
# 1662

# %%
# Strip whitespace and quotes, then map to binary
df['eu_status'] = df['eu_status'].astype(str).str.strip().str.replace('"', '')
df_gdpr_window['eu_status'] = df_gdpr_window['eu_status'].map({'Yes': 'EU', 'No': 'Non-EU'})
# Out:
# C:\Users\Ethan D\AppData\Local\Temp\ipykernel_10472\1599210010.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdpr_window['eu_status'] = df_gdpr_window['eu_status'].map({'Yes': 'EU', 'No': 'Non-EU'})

# %%
print("After:", df['eu_status'].unique())
# Out:
# After: ['0' '1']

# %%
import matplotlib.pyplot as plt
## look at average rating over monthly period and also for eu and on eu comapnies
# Create a month column
df_gdpr_window['month'] = df_gdpr_window['date'].dt.to_period('M')

# Group by month and EU status, then calculate average rating
monthly_avg = df_gdpr_window.groupby(['month', 'eu_status'])['rating'].mean().reset_index()

# Convert month back to timestamp for plotting
monthly_avg['month'] = monthly_avg['month'].dt.to_timestamp()

# Pivot for easier plotting
pivot_df = monthly_avg.pivot(index='month', columns='eu_status', values='rating')

# Plot
plt.figure(figsize=(12, 6))
pivot_df.plot(ax=plt.gca(), marker='o')
plt.axvline(pd.to_datetime('2018-05-25'), color='red', linestyle='--', label='GDPR Implementation')
plt.title('Average Employee Rating (Monthly) for EU vs Non-EU Companies')
plt.xlabel('Month')
plt.ylabel('Average Rating')
plt.grid(True)
plt.legend(title='Eu status')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ethan D\AppData\Local\Temp\ipykernel_10472\2336323090.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdpr_window['month'] = df_gdpr_window['date'].dt.to_period('M')

# %%
# Save the GDPR-focused DataFrame to CSV
df_gdpr_window.to_csv("df_2_year_window.csv", index=False)

# %%
df_gdpr_window.sample(10)
# Out:
#          rating                                              title  \
# 2794838     2.0                                 stepping stone job
# 5926528     4.0                       Good summer job for students
# 968783      5.0  Awesome Place to Work in with great Learning O...
# 3375889     5.0                                                 DM
# 1132366     5.0              Construction Company Office Assistant
# 1839544     3.0                         Solid entry level position
# 3072885     4.0  It doesn't get better in terms of perks, could...
# 2791787     3.0                                  Software Engineer
# 5621229     4.0                    Process Integration Development
# 3826176     4.0                                      Sales Manager
#
#                                       status  \
# 2794838  Current Employee, more than 5 years
# 5926528    Former Employee, less than 1 year
# 968783    Current Employee, less than 1 year
# ...

# %%
# Combine 'title', 'pros', and 'cons' into a new 'full_review' column
df_gdpr_window['full_review'] = (
    df_gdpr_window['title'].fillna('') + ' ' +
    df_gdpr_window['pros'].fillna('') + ' ' +
    df_gdpr_window['cons'].fillna('')
)

# Clean the combined text (lowercase, strip whitespace, remove special characters)
df_gdpr_window['full_review'] = (
    df_gdpr_window['full_review']
    .str.lower()
    .str.replace(r'[^\w\s]', '', regex=True)  # remove special characters
    .str.strip()
)

# %%
# Drop 'title', 'pros', and 'cons' columns
df_gdpr_window.drop(columns=['title', 'pros', 'cons', 'status'], inplace=True)
df_gdpr_window.sample(20)
# Out:
# C:\Users\Ethan D\AppData\Local\Temp\ipykernel_10472\4247778327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdpr_window.drop(columns=['status'], inplace=True)
#          rating       date                                        job  \
# 573551      5.0 2020-05-21   Research Assistant and Software Engineer
# 7654652     3.0 2019-05-24                                  Associate
# 1801025     2.0 2019-03-05                              IT Generalist
# 4424649     3.0 2017-04-19                         Anonymous Employee
# 1786760     2.0 2018-02-07                         Anonymous Employee
# 5315068     5.0 2020-01-05                                Commtech IV
# 4143728     3.0 2018-07-17                           Project Engineer
# ...

# %%
print(df_gdpr_window.isnull().sum())
# Out:
# rating                            0
# date                              0
# job                               0
# company_name                      0
# CEO_Approval_Sentiment            0
# Business_Outlook_Sentiment        0
# Recommmend_sentiment              0
# company_size                      0
# eu_status                     70627
# founded_year                      0
# under_gdpr                        0
# industry                          0
# seniority_level                   0
# month                             0
# full_review                       0
# dtype: int64

# %%
missing_rows = df_gdpr_window[df_gdpr_window.isnull().any(axis=1)]
print(missing_rows.head(20))
# Out:
#       rating       date                           job company_name  \
# 3520     2.0 2019-08-26    Keyholder/Brand Ambassador    Swarovski
# 3525     2.0 2016-10-31            Anonymous Employee    Swarovski
# 3530     4.0 2019-07-31                    Key Holder    Swarovski
# 3534     1.0 2017-10-28        District Sales Manager    Swarovski
# 3551     3.0 2019-04-23                 Store Manager    Swarovski
# 3552     3.0 2017-06-18               Sales Associate    Swarovski
# 3553     1.0 2020-01-09            Anonymous Employee    Swarovski
# 3556     1.0 2017-01-12            Anonymous Employee    Swarovski
# 3558     3.0 2017-07-26          Retail Store Manager    Swarovski
# 3575     3.0 2018-06-04            Anonymous Employee    Swarovski
# 3576     1.0 2019-06-10                       Manager    Swarovski
# 3577     3.0 2019-04-27               Sales Associate    Swarovski
# 3580     2.0 2017-09-05                 Store Manager    Swarovski
# ...

# %%
df.sample(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.sample(10)
#
# NameError: name 'df' is not defined
